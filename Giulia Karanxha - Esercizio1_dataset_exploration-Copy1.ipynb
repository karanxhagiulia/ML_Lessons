# %%
### importare pandas, seaborn e matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### IMPORT DEI DATI

# %% [markdown]
# I dati sono nella cartella in formato .csv, sotto il nome 'Car details v3.csv'. Caricare il csv in DataFrame Pandas. NB. il dataset originale è disponibile qui: https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho?select=Car+details+v3.csv

# %%
### importare i dati con pd.read_csv()
cars_df = pd.read_csv('Giulia Karanxha - cars.csv') 
cars_df
# Out:
#       Unnamed: 0  Unnamed: 0.1                          name  year  \
# 0              0             0        Maruti Swift Dzire VDI  2014
# 1              1             1  Skoda Rapid 1.5 TDI Ambition  2014
# 2              2             2      Honda City 2017-2020 EXi  2006
# 3              3             3     Hyundai i20 Sportz Diesel  2010
# 4              4             4        Maruti Swift VXI BSIII  2007
# ...          ...           ...                           ...   ...
# 7901        8123          8123             Hyundai i20 Magna  2013
# 7902        8124          8124         Hyundai Verna CRDi SX  2007
# 7903        8125          8125        Maruti Swift Dzire ZDi  2009
# 7904        8126          8126               Tata Indigo CR4  2013
# 7905        8127          8127               Tata Indigo CR4  2013
#
#       selling_price  km_driven    fuel seller_type transmission  \
# 0            450000     145500  Diesel  Individual       Manual
# 1            370000     120000  Diesel  Individual       Manual
# 2            158000     140000  Petrol  Individual       Manual
# 3            225000     127000  Diesel  Individual       Manual
# 4            130000     120000  Petrol  Individual       Manual
# ...             ...        ...     ...         ...          ...
# 7901         320000     110000  Petrol  Individual       Manual
# 7902         135000     119000  Diesel  Individual       Manual
# 7903         382000     120000  Diesel  Individual       Manual
# 7904         290000      25000  Diesel  Individual       Manual
# 7905         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  \
# 0              First Owner    23.40  1248.0      74.00
# 1             Second Owner    21.14  1498.0     103.52
# 2              Third Owner    17.70  1497.0      78.00
# 3              First Owner    23.00  1396.0      90.00
# 4              First Owner    16.10  1298.0      88.20
# ...                    ...      ...     ...        ...
# 7901           First Owner    18.50  1197.0      82.85
# 7902  Fourth & Above Owner    16.80  1493.0     110.00
# 7903           First Owner    19.30  1248.0      73.90
# 7904           First Owner    23.57  1396.0      70.00
# 7905           First Owner    23.57  1396.0      70.00
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 7901           113.7Nm@ 4000rpm    5.0
# 7902  24@ 1,900-2,750(kgm@ rpm)    5.0
# 7903             190Nm@ 2000rpm    5.0
# 7904        140Nm@ 1800-3000rpm    5.0
# 7905        140Nm@ 1800-3000rpm    5.0
#
# [7906 rows x 15 columns]

# %%
### printare le informazioni sul DataFrame con .info()
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     7906 non-null   int64
#  1   Unnamed: 0.1   7906 non-null   int64
#  2   name           7906 non-null   object
#  3   year           7906 non-null   int64
#  4   selling_price  7906 non-null   int64
#  5   km_driven      7906 non-null   int64
#  6   fuel           7906 non-null   object
#  7   seller_type    7906 non-null   object
#  8   transmission   7906 non-null   object
#  9   owner          7906 non-null   object
#  10  mileage        7906 non-null   float64
#  11  engine         7906 non-null   float64
#  12  max_power      7906 non-null   float64
#  13  torque         7906 non-null   object
#  14  seats          7906 non-null   float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 926.6+ KB

# %%
### printare le prime 5 righe con .head()
cars_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                          name  year  \
# 0           0             0        Maruti Swift Dzire VDI  2014
# 1           1             1  Skoda Rapid 1.5 TDI Ambition  2014
# 2           2             2      Honda City 2017-2020 EXi  2006
# 3           3             3     Hyundai i20 Sportz Diesel  2010
# 4           4             4        Maruti Swift VXI BSIII  2007
#
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power                    torque  seats
# 0    23.40  1248.0      74.00            190Nm@ 2000rpm    5.0
# 1    21.14  1498.0     103.52       250Nm@ 1500-2500rpm    5.0
# 2    17.70  1497.0      78.00     12.7@ 2,700(kgm@ rpm)    5.0
# 3    23.00  1396.0      90.00  22.4 kgm at 1750-2750rpm    5.0
# 4    16.10  1298.0      88.20     11.5@ 4,500(kgm@ rpm)    5.0

# %% [markdown]
# ### VALUTAZIONE SOGGETTIVA

# %% [markdown]
# Il TARGET è 'selling_price'. Occhio che il prozzo non è in EURO, ma in una valuta che non conosco, quindi non spaventatevi se vedete numeri molto alti. Scrivere qui sotto in forma di commento qualche osservazione su quali potrebbero essere le variabili più importanti e perchè.

# %%
### Colonna year, km_driven, transmission (in base al paese), mileage, engine, max power, seats

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     7906 non-null   int64
#  1   Unnamed: 0.1   7906 non-null   int64
#  2   name           7906 non-null   object
#  3   year           7906 non-null   int64
#  4   selling_price  7906 non-null   int64
#  5   km_driven      7906 non-null   int64
#  6   fuel           7906 non-null   object
#  7   seller_type    7906 non-null   object
#  8   transmission   7906 non-null   object
#  9   owner          7906 non-null   object
#  10  mileage        7906 non-null   float64
#  11  engine         7906 non-null   float64
#  12  max_power      7906 non-null   float64
#  13  torque         7906 non-null   object
#  14  seats          7906 non-null   float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 926.6+ KB

# %% [markdown]
# ### ESPLORAZIONE DELLA VARIABILE TARGET

# %%
### usare sns.displot() per plottare la distribuzione (ricordate di passare un numero adeguato di bins)

sns.displot(data=cars_df['selling_price'], bins = 500);

# %%
### fare un print di skweness e kurtosis
print('Skewness:', cars_df['selling_price'].skew())
print('Kurtosis:', cars_df['selling_price'].kurt())
# Out:
# Skewness: 4.156863952749261
# Kurtosis: 20.634384495838116

# %% [markdown]
# ### RELAZIONI CON ALTRE VARIABILI NUMERICHE

# %%
### fare lo scatterplot() di ogni variabile numeriche (km_driven, seats, max_power, engine, mileage) contro il target
sns.scatterplot(x='km_driven', y='selling_price', data=cars_df).set_xlim(right=800000);

# %%
#usare un ciclo for per fare lo scatterplot delle colonne che voglio
for col in ['max_power', 'km_driven', 'seats', 'engine']:
  sns.scatterplot(x=col, y='selling_price', data=cars_df)

# %%
sns.scatterplot(x='seats', y='selling_price', data=cars_df);

# %%
sns.scatterplot(x='max_power', y='selling_price', data=cars_df).set_xlim(right=300);

# %%
sns.scatterplot(x='engine', y='selling_price', data=cars_df);

# %%
sns.scatterplot(x='mileage', y='selling_price', data=cars_df);

# %% [markdown]
# ### RELAZIONI CON ALTRE VARIABILI CATEGORICHE

# %% [markdown]
# ####Utilizzando il ciclo for

# %%
### usare sns.boxplot per plottare ogni variabile categorica (year, fuel, seller_type, transmission, owner) contro il target

for col in ['year', 'fuel', 'seller_type', 'transmission', 'owner', 'torque']:
  plt.figure(figsize=(35,17))
  sns.boxplot(x=col, y="selling_price", data=cars_df)
  plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
  plt.show()

# %%
sns.boxplot(x='year', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %%
sns.boxplot(x='fuel', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %%
sns.boxplot(x='seller_type', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %%
sns.boxplot(x='transmission', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %%
sns.boxplot(x='owner', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %%
plt.figure(figsize=(35,11))
sns.boxplot(x='torque', y="selling_price", data=cars_df)
plt.xticks(rotation=90, fontsize=13) # ruota le etichette sull'asse x
plt.show()

# %% [markdown]
# ### CORRELAZIONI

# %%
corr_matrix = cars_df.corr()
corr_matrix
corr_matrix['selling_price'].sort_values(ascending=False)
# Out:
# selling_price    1.000000
# max_power        0.749674
# engine           0.455682
# year             0.412302
# seats            0.041617
# Unnamed: 0      -0.012125
# Unnamed: 0.1    -0.012125
# mileage         -0.126280
# km_driven       -0.222158
# Name: selling_price, dtype: float64

# %%
sale_corr = corr_matrix['selling_price'].abs().sort_values(ascending=False)

plt.figure(figsize=(10,7))
sns.barplot(x=sale_corr.index, y=sale_corr)
plt.xticks(rotation=90, fontsize=12)
plt.show()

# %%
sale_corr
# Out:
# selling_price    1.000000
# max_power        0.749674
# engine           0.455682
# year             0.412302
# km_driven        0.222158
# mileage          0.126280
# seats            0.041617
# Unnamed: 0       0.012125
# Unnamed: 0.1     0.012125
# Name: selling_price, dtype: float64

# %%
most_corr_vars = sale_corr.abs().iloc[0:7].index
most_corr_vars
# Out:
# Index(['selling_price', 'max_power', 'engine', 'year', 'km_driven', 'mileage',
#        'seats'],
#       dtype='object')

# %%
 cars_df[most_corr_vars].corr()
# Out:
#                selling_price  max_power    engine      year  km_driven  \
# selling_price       1.000000   0.749674  0.455682  0.412302  -0.222158
# max_power           0.749674   1.000000  0.703975  0.226598  -0.038159
# engine              0.455682   0.703975  1.000000  0.018263   0.206031
# year                0.412302   0.226598  0.018263  1.000000  -0.428548
# km_driven          -0.222158  -0.038159  0.206031 -0.428548   1.000000
# mileage            -0.126280  -0.374621 -0.576408  0.328544  -0.172980
# seats               0.041617   0.191999  0.611103 -0.007923   0.227259
#
#                 mileage     seats
# selling_price -0.126280  0.041617
# max_power     -0.374621  0.191999
# engine        -0.576408  0.611103
# year           0.328544 -0.007923
# km_driven     -0.172980  0.227259
# mileage        1.000000 -0.451700
# seats         -0.451700  1.000000

# %%
# plottare la matrice di correlazione con sns.heatmap() e individuare le variabili più correlate con selling_price, oltre che quelle che sembrano essere collineari tra loro
most_corr_vars = sale_corr.abs().iloc[0:7].index
most_corr_matrix = cars_df[most_corr_vars].corr()
#è selling price non la quantità venduta, quindi è giusto che il prezzo di vendita è inversamente proporzionato al numero di km fatti
plt.figure(figsize=(8,7))
sns.heatmap(most_corr_matrix, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10})
plt.show()

# %% [markdown]
# Ora vediamo le correlazioni con SalePrice

# %% [markdown]
# Volendo Seaborn mette a disposizione la funzione pairplot() per visualizzare gli scatterplot incrociati e le distribuzioni delle variabili...

# %%
### plottare il pairplot di seaborn
sns.pairplot(data=cars_df[most_corr_vars]);

# %%
#per sapere quante categorie ha una variabile

set(cars_df['seats'])
# Out:
# {2.0, 4.0, 5.0, 6.0, 7.0, 8.0, 9.0, 10.0, 14.0}

# %% [markdown]
# #Drop di una colonna

# %%
df = cars_df.drop('Unnamed: 0', axis=1)#per cancellare una colonna, utilizzo drop. Specifico l'axis perché axis=1 per droppare la colonna, axis=0 è la riga
df


# Remove two columns name is 'C' and 'D'
#df.drop(['C', 'D'], axis = 1)
